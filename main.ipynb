# %% [markdown]
# # International Passenger Survey 4.01, citizenship group by sex by age by country of last or next residence
#
# Convert all tabs from latest Excel spreadsheet available from https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipscitizenshipgroupbysexbyagebycountryoflastornextresidence

# %%
from gssutils import *

scraper = Scraper('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/ipscitizenshipgroupbysexbyagebycountryoflastornextresidence')
scraper
# Out:
# ## International Passenger Survey 4.01, citizenship group by sex by age by country of last or next residence
#
# International Passenger Survey detailed estimates of Long-Term International Migration: Citizenship, sex and age by country of last or next residence. UK, Underlying datasheet 1.
#
# ### Distributions
#
# 1. International Passenger Survey 4.01, citizenship group by sex by age by country of last or next residence ([MS Excel Spreadsheet](https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipscitizenshipgroupbysexbyagebycountryoflastornextresidence/2017/underlyingdatasheet4.01ipscitizenshipgroupbysexbyagebycountryoflastornextresidence2017.xls))

# %%
tabs = scraper.distribution().as_databaker()
# Out:
# WARNING:Cache entry deserialization failed, entry ignored

# %% [markdown]
# Each tab is of the same form, with "software readable codes":
#
# > The datasheets can be imported directly into suitable software. When importing the datasheets into other software import only rows 8 to 1448, starting at column F.

# %%
tidied_sheets = []

for tab in tabs:
    if not tab.name.startswith('Data'):
        continue
    year = int(tab.excel_ref('A2').value[-4:])
    start = tab.excel_ref('F8')
    end = tab.excel_ref('F1448')
    #end = tab.excel_ref('F48')
    codes = start.fill(DOWN) & end.expand(UP)
    observations = codes.fill(RIGHT).is_not_whitespace()
    country = start.shift(RIGHT).fill(RIGHT)
    country_ci = country.regex(r'^.*CI\s*$')
    country_est = country - country_ci
    observations_est = observations & country_est.fill(DOWN)
    observations_ci = observations & country_ci.fill(DOWN)
    cs_est = ConversionSegment(observations_est, [
        HDimConst('Year', year),
        HDim(codes, 'Code', DIRECTLY, LEFT),
        HDim(country_est, 'Country of Residence', DIRECTLY, ABOVE),
        HDim(observations_ci, 'CI', DIRECTLY, RIGHT),
        HDimConst('Measure Type', 'Count'),
        HDimConst('Unit', 'people-thousands')
    ])
    #savepreviewhtml(cs_est)
    tidy_sheet = cs_est.topandas()
    tidy_sheet = tidy_sheet[pd.isna(tidy_sheet['DATAMARKER'])].copy() # Todo: data markers
    tidy_sheet.drop(columns=['DATAMARKER'], inplace=True)
    tidy_sheet.rename(columns={'OBS': 'Value'}, inplace=True)
    tidied_sheets.append(tidy_sheet)
tidy = pd.concat(tidied_sheets)
tidy
# Out:
#        Value  Year                                               Code  \
# 0      253.1  2017                  INFLOW, CIT All, Persons, Age All
# 1      141.9  2017                  INFLOW, CIT All, Persons, Age All
# 2       48.8  2017                  INFLOW, CIT All, Persons, Age All
# 3       52.7  2017                  INFLOW, CIT All, Persons, Age All
# 4        255  2017                  INFLOW, CIT All, Persons, Age All
# 5      259.3  2017                  INFLOW, CIT All, Persons, Age All
# 6      347.6  2017                  INFLOW, CIT All, Persons, Age All
# 7      165.4  2017                  INFLOW, CIT All, Persons, Age All
# 8       60.9  2017                  INFLOW, CIT All, Persons, Age All
# 9      104.5  2017                  INFLOW, CIT All, Persons, Age All
# 10     182.3  2017                  INFLOW, CIT All, Persons, Age All
# 11     272.9  2017                  INFLOW, CIT All, Persons, Age All
# 12      19.9  2017                  INFLOW, CIT All, Persons, Age All
# 13     201.4  2017                  INFLOW, CIT All, Persons, Age All
# 14      24.9  2017                  INFLOW, CIT All, Persons, Age All
# 15      81.3  2017                  INFLOW, CIT All, Persons, Age All
# 16        69  2017                  INFLOW, CIT All, Persons, Age All
# 17      26.2  2017                  INFLOW, CIT All, Persons, Age All
# 18     126.4  2017                  INFLOW, CIT All, Persons, Age All
# 19       2.7  2017                  INFLOW, CIT All, Persons, Age All
# 20      29.5  2017                  INFLOW, CIT All, Persons, Age All
# 21      39.8  2017                  INFLOW, CIT All, Persons, Age All
# 22       8.4  2017                  INFLOW, CIT All, Persons, Age All
# 23        46  2017                  INFLOW, CIT All, Persons, Age All
# 24       2.6  2017                  INFLOW, CIT All, Persons, AGQ 0-4
# 25       1.2  2017                  INFLOW, CIT All, Persons, AGQ 0-4
# 26       0.4  2017                  INFLOW, CIT All, Persons, AGQ 0-4
# 27         1  2017                  INFLOW, CIT All, Persons, AGQ 0-4
# 28       2.6  2017                  INFLOW, CIT All, Persons, AGQ 0-4
# 29       2.6  2017                  INFLOW, CIT All, Persons, AGQ 0-4
# ...      ...   ...                                                ...
# 63204    2.3  2017  BALANCE, CIT Not British or British Overseas, ...
# 63205   -3.3  2017  BALANCE, CIT Not British or British Overseas, ...
# 63206    0.4  2017  BALANCE, CIT Not British or British Overseas, ...
# 63208      0  2017  BALANCE, CIT Not British or British Overseas, ...
# 63210   -0.5  2017  BALANCE, CIT Not British or British Overseas, ...
# 63211   -0.2  2017  BALANCE, CIT Not British or British Overseas, ...
# 63213    0.5  2017  BALANCE, CIT Not British or British Overseas, ...
# 63214    0.2  2017  BALANCE, CIT Not British or British Overseas, ...
# 63215    0.2  2017  BALANCE, CIT Not British or British Overseas, ...
# 63216    0.6  2017  BALANCE, CIT Not British or British Overseas, ...
# 63217    1.6  2017  BALANCE, CIT Not British or British Overseas, ...
# 63219    0.7  2017  BALANCE, CIT Not British or British Overseas, ...
# 63221    0.8  2017  BALANCE, CIT Not British or British Overseas, ...
# 63222    2.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63224   -0.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63227    0.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63229    0.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63233    0.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63234    3.7  2017  BALANCE, CIT Not British or British Overseas, ...
# 63235    0.3  2017  BALANCE, CIT Not British or British Overseas, ...
# 63238    0.3  2017  BALANCE, CIT Not British or British Overseas, ...
# 63242    0.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63248      1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63254   -0.5  2017  BALANCE, CIT Not British or British Overseas, ...
# 63266    0.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63282    0.8  2017  BALANCE, CIT Not British or British Overseas, ...
# 63317    0.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63326    0.4  2017  BALANCE, CIT Not British or British Overseas, ...
# 63338    0.1  2017  BALANCE, CIT Not British or British Overseas, ...
# 63354   -0.4  2017  BALANCE, CIT Not British or British Overseas, ...
#
#                         Country of Residence    CI Measure Type  \
# 0                                RESC EU EST  29.6        Count
# 1                              RESC EU15 EST  22.5        Count
# 2                               RESC EU8 EST  11.6        Count
# 3                               RESC EU2 EST  13.0        Count
# 4                               RESC EEA EST  29.8        Count
# 5                              RESC EFTA EST  30.1        Count
# 6                            RESC Non-EU EST  26.5        Count
# 7                                RESC CW EST  18.5        Count
# 8                            RESC Old CW EST  13.1        Count
# 9                            RESC New CW EST  13.2        Count
# 10                RESC Non-EU and Non-CW EST  19.0        Count
# 11                    RESC Europe inc EU EST  30.9        Count
# 12                    RESC Europe exc EU EST   8.8        Count
# 13                             RESC Asia EST  18.2        Count
# 14     RESC Middle East and Central Asia EST   7.0        Count
# 15                        RESC East Asia EST  11.6        Count
# 16                       RESC South Asia EST  10.3        Count
# 17                  RESC South East Asia EST   6.3        Count
# 18                    RESC Rest of World EST  17.2        Count
# 19                     RESC North Africa EST   1.9        Count
# 20               RESC Sub-Saharan Africa EST   7.3        Count
# 21                    RESC North America EST   9.6        Count
# 22        RESC Central and South America EST   3.4        Count
# 23                          RESC Oceania EST  11.7        Count
# 24                               RESC EU EST   2.2        Count
# 25                             RESC EU15 EST   1.3        Count
# 26                              RESC EU8 EST   0.8        Count
# 27                              RESC EU2 EST   1.6        Count
# 28                              RESC EEA EST   2.2        Count
# 29                             RESC EFTA EST   2.2        Count
# ...                                      ...   ...          ...
# 63204                  RESC South Africa EST   2.4        Count
# 63205                         RESC Spain EST   5.1        Count
# 63206                     RESC Sri Lanka EST   0.5        Count
# 63208                         RESC Sudan EST   0.1        Count
# 63210                        RESC Sweden EST   0.7        Count
# 63211                   RESC Switzerland EST   1.3        Count
# 63213                        RESC Taiwan EST   2.0        Count
# 63214                      RESC Tanzania EST   0.5        Count
# 63215                      RESC Thailand EST   0.9        Count
# 63216           RESC Trinidad and Tobago EST   1.2        Count
# 63217                        RESC Turkey EST   2.6        Count
# 63219                        RESC Uganda EST   1.4        Count
# 63221          RESC United Arab Emirates EST   0.6        Count
# 63222                           RESC USA EST   2.6        Count
# 63224                       RESC Vietnam EST   0.3        Count
# 63227                      RESC Zimbabwe EST   0.1        Count
# 63229                      RESC Pakistan EST   0.1        Count
# 63233                   RESC Philippines EST   0.2        Count
# 63234                        RESC Poland EST   5.1        Count
# 63235                      RESC Portugal EST   0.5        Count
# 63238                       RESC Romania EST   0.5        Count
# 63242                        RESC Serbia EST   0.2        Count
# 63248                  RESC South Africa EST   1.3        Count
# 63254                        RESC Sweden EST   1.0        Count
# 63266                           RESC USA EST   1.0        Count
# 63282                       RESC Romania EST   1.1        Count
# 63317                      RESC Pakistan EST   0.2        Count
# 63326                       RESC Romania EST   0.7        Count
# 63338                     RESC Sri Lanka EST   0.2        Count
# 63354                           RESC USA EST   0.7        Count
#
#                    Unit
# 0      people-thousands
# 1      people-thousands
# 2      people-thousands
# 3      people-thousands
# 4      people-thousands
# 5      people-thousands
# 6      people-thousands
# 7      people-thousands
# 8      people-thousands
# 9      people-thousands
# 10     people-thousands
# 11     people-thousands
# 12     people-thousands
# 13     people-thousands
# 14     people-thousands
# 15     people-thousands
# 16     people-thousands
# 17     people-thousands
# 18     people-thousands
# 19     people-thousands
# 20     people-thousands
# 21     people-thousands
# 22     people-thousands
# 23     people-thousands
# 24     people-thousands
# 25     people-thousands
# 26     people-thousands
# 27     people-thousands
# 28     people-thousands
# 29     people-thousands
# ...                 ...
# 63204  people-thousands
# 63205  people-thousands
# 63206  people-thousands
# 63208  people-thousands
# 63210  people-thousands
# 63211  people-thousands
# 63213  people-thousands
# 63214  people-thousands
# 63215  people-thousands
# 63216  people-thousands
# 63217  people-thousands
# 63219  people-thousands
# 63221  people-thousands
# 63222  people-thousands
# 63224  people-thousands
# 63227  people-thousands
# 63229  people-thousands
# 63233  people-thousands
# 63234  people-thousands
# 63235  people-thousands
# 63238  people-thousands
# 63242  people-thousands
# 63248  people-thousands
# 63254  people-thousands
# 63266  people-thousands
# 63282  people-thousands
# 63317  people-thousands
# 63326  people-thousands
# 63338  people-thousands
# 63354  people-thousands
#
# [52189 rows x 7 columns]

# %%
def residence_country_code(s):
    code = pathify(s)
    assert code.startswith('resc-'), code
    code = code[5:]
    assert code.endswith('-est'), code
    code = code[:-4]
    return code.replace('-/-', '-')

tidy['Country of Residence'] = tidy['Country of Residence'].apply(residence_country_code)
codes_table = tidy['Code'].str.split(', ', expand=True)
tidy['Migration Flow'] = codes_table[0]
tidy['IPS Citizenship'] = codes_table[1]
tidy['Sex'] = codes_table[2]
tidy['Age'] = codes_table[3]
tidy = tidy[['Year','Country of Residence','Migration Flow',
             'IPS Citizenship','Sex','Age',
             'Measure Type','Value','CI','Unit']]
tidy
# Out:
#        Year          Country of Residence Migration Flow  \
# 0      2017                            eu         INFLOW
# 1      2017                          eu15         INFLOW
# 2      2017                           eu8         INFLOW
# 3      2017                           eu2         INFLOW
# 4      2017                           eea         INFLOW
# 5      2017                          efta         INFLOW
# 6      2017                        non-eu         INFLOW
# 7      2017                            cw         INFLOW
# 8      2017                        old-cw         INFLOW
# 9      2017                        new-cw         INFLOW
# 10     2017             non-eu-and-non-cw         INFLOW
# 11     2017                 europe-inc-eu         INFLOW
# 12     2017                 europe-exc-eu         INFLOW
# 13     2017                          asia         INFLOW
# 14     2017  middle-east-and-central-asia         INFLOW
# 15     2017                     east-asia         INFLOW
# 16     2017                    south-asia         INFLOW
# 17     2017               south-east-asia         INFLOW
# 18     2017                 rest-of-world         INFLOW
# 19     2017                  north-africa         INFLOW
# 20     2017            sub-saharan-africa         INFLOW
# 21     2017                 north-america         INFLOW
# 22     2017     central-and-south-america         INFLOW
# 23     2017                       oceania         INFLOW
# 24     2017                            eu         INFLOW
# 25     2017                          eu15         INFLOW
# 26     2017                           eu8         INFLOW
# 27     2017                           eu2         INFLOW
# 28     2017                           eea         INFLOW
# 29     2017                          efta         INFLOW
# ...     ...                           ...            ...
# 63204  2017                  south-africa        BALANCE
# 63205  2017                         spain        BALANCE
# 63206  2017                     sri-lanka        BALANCE
# 63208  2017                         sudan        BALANCE
# 63210  2017                        sweden        BALANCE
# 63211  2017                   switzerland        BALANCE
# 63213  2017                        taiwan        BALANCE
# 63214  2017                      tanzania        BALANCE
# 63215  2017                      thailand        BALANCE
# 63216  2017           trinidad-and-tobago        BALANCE
# 63217  2017                        turkey        BALANCE
# 63219  2017                        uganda        BALANCE
# 63221  2017          united-arab-emirates        BALANCE
# 63222  2017                           usa        BALANCE
# 63224  2017                       vietnam        BALANCE
# 63227  2017                      zimbabwe        BALANCE
# 63229  2017                      pakistan        BALANCE
# 63233  2017                   philippines        BALANCE
# 63234  2017                        poland        BALANCE
# 63235  2017                      portugal        BALANCE
# 63238  2017                       romania        BALANCE
# 63242  2017                        serbia        BALANCE
# 63248  2017                  south-africa        BALANCE
# 63254  2017                        sweden        BALANCE
# 63266  2017                           usa        BALANCE
# 63282  2017                       romania        BALANCE
# 63317  2017                      pakistan        BALANCE
# 63326  2017                       romania        BALANCE
# 63338  2017                     sri-lanka        BALANCE
# 63354  2017                           usa        BALANCE
#
#                            IPS Citizenship      Sex          Age Measure Type  \
# 0                                  CIT All  Persons      Age All        Count
# 1                                  CIT All  Persons      Age All        Count
# 2                                  CIT All  Persons      Age All        Count
# 3                                  CIT All  Persons      Age All        Count
# 4                                  CIT All  Persons      Age All        Count
# 5                                  CIT All  Persons      Age All        Count
# 6                                  CIT All  Persons      Age All        Count
# 7                                  CIT All  Persons      Age All        Count
# 8                                  CIT All  Persons      Age All        Count
# 9                                  CIT All  Persons      Age All        Count
# 10                                 CIT All  Persons      Age All        Count
# 11                                 CIT All  Persons      Age All        Count
# 12                                 CIT All  Persons      Age All        Count
# 13                                 CIT All  Persons      Age All        Count
# 14                                 CIT All  Persons      Age All        Count
# 15                                 CIT All  Persons      Age All        Count
# 16                                 CIT All  Persons      Age All        Count
# 17                                 CIT All  Persons      Age All        Count
# 18                                 CIT All  Persons      Age All        Count
# 19                                 CIT All  Persons      Age All        Count
# 20                                 CIT All  Persons      Age All        Count
# 21                                 CIT All  Persons      Age All        Count
# 22                                 CIT All  Persons      Age All        Count
# 23                                 CIT All  Persons      Age All        Count
# 24                                 CIT All  Persons      AGQ 0-4        Count
# 25                                 CIT All  Persons      AGQ 0-4        Count
# 26                                 CIT All  Persons      AGQ 0-4        Count
# 27                                 CIT All  Persons      AGQ 0-4        Count
# 28                                 CIT All  Persons      AGQ 0-4        Count
# 29                                 CIT All  Persons      AGQ 0-4        Count
# ...                                    ...      ...          ...          ...
# 63204  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63205  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63206  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63208  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63210  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63211  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63213  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63214  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63215  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63216  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63217  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63219  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63221  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63222  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63224  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63227  CIT Not British or British Overseas   Female    AG2 25-44        Count
# 63229  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63233  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63234  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63235  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63238  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63242  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63248  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63254  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63266  CIT Not British or British Overseas   Female    AG2 45-59        Count
# 63282  CIT Not British or British Overseas   Female    AG2 60-64        Count
# 63317  CIT Not British or British Overseas   Female  AG2 65 plus        Count
# 63326  CIT Not British or British Overseas   Female  AG2 65 plus        Count
# 63338  CIT Not British or British Overseas   Female  AG2 65 plus        Count
# 63354  CIT Not British or British Overseas   Female  AG2 65 plus        Count
#
#        Value    CI              Unit
# 0      253.1  29.6  people-thousands
# 1      141.9  22.5  people-thousands
# 2       48.8  11.6  people-thousands
# 3       52.7  13.0  people-thousands
# 4        255  29.8  people-thousands
# 5      259.3  30.1  people-thousands
# 6      347.6  26.5  people-thousands
# 7      165.4  18.5  people-thousands
# 8       60.9  13.1  people-thousands
# 9      104.5  13.2  people-thousands
# 10     182.3  19.0  people-thousands
# 11     272.9  30.9  people-thousands
# 12      19.9   8.8  people-thousands
# 13     201.4  18.2  people-thousands
# 14      24.9   7.0  people-thousands
# 15      81.3  11.6  people-thousands
# 16        69  10.3  people-thousands
# 17      26.2   6.3  people-thousands
# 18     126.4  17.2  people-thousands
# 19       2.7   1.9  people-thousands
# 20      29.5   7.3  people-thousands
# 21      39.8   9.6  people-thousands
# 22       8.4   3.4  people-thousands
# 23        46  11.7  people-thousands
# 24       2.6   2.2  people-thousands
# 25       1.2   1.3  people-thousands
# 26       0.4   0.8  people-thousands
# 27         1   1.6  people-thousands
# 28       2.6   2.2  people-thousands
# 29       2.6   2.2  people-thousands
# ...      ...   ...               ...
# 63204    2.3   2.4  people-thousands
# 63205   -3.3   5.1  people-thousands
# 63206    0.4   0.5  people-thousands
# 63208      0   0.1  people-thousands
# 63210   -0.5   0.7  people-thousands
# 63211   -0.2   1.3  people-thousands
# 63213    0.5   2.0  people-thousands
# 63214    0.2   0.5  people-thousands
# 63215    0.2   0.9  people-thousands
# 63216    0.6   1.2  people-thousands
# 63217    1.6   2.6  people-thousands
# 63219    0.7   1.4  people-thousands
# 63221    0.8   0.6  people-thousands
# 63222    2.1   2.6  people-thousands
# 63224   -0.1   0.3  people-thousands
# 63227    0.1   0.1  people-thousands
# 63229    0.1   0.1  people-thousands
# 63233    0.1   0.2  people-thousands
# 63234    3.7   5.1  people-thousands
# 63235    0.3   0.5  people-thousands
# 63238    0.3   0.5  people-thousands
# 63242    0.1   0.2  people-thousands
# 63248      1   1.3  people-thousands
# 63254   -0.5   1.0  people-thousands
# 63266    0.1   1.0  people-thousands
# 63282    0.8   1.1  people-thousands
# 63317    0.1   0.2  people-thousands
# 63326    0.4   0.7  people-thousands
# 63338    0.1   0.2  people-thousands
# 63354   -0.4   0.7  people-thousands
#
# [52189 rows x 10 columns]

# %%
from IPython.core.display import HTML
for col in tidy:
    if col not in ['Value', 'CI']:
        tidy[col] = tidy[col].astype('category')
        display(HTML(f"<h2>{col}</h2>"))
        display(tidy[col].cat.categories)
# Out:
# <h2>Year</h2>
# Int64Index([2017], dtype='int64')
# <h2>Country of Residence</h2>
# Index(['afghanistan', 'albania', 'algeria', 'angola',
#        'antarctica-not-otherwise-specified', 'argentina', 'asia', 'australia',
#        'austria', 'azerbaijan',
#        ...
#        'turks-and-caicos-islands', 'uganda', 'ukraine', 'united-arab-emirates',
#        'usa', 'uzbekistan', 'vietnam', 'yemen', 'zambia', 'zimbabwe'],
#       dtype='object', length=154)
# <h2>Migration Flow</h2>
# Index(['BALANCE', 'INFLOW', 'OUTFLOW'], dtype='object')
# <h2>IPS Citizenship</h2>
# Index(['CIT All', 'CIT British', 'CIT British or British Overseas',
#        'CIT Non-British', 'CIT Not British or British Overseas'],
#       dtype='object')
# <h2>Sex</h2>
# Index(['Female', 'Male', 'Persons'], dtype='object')
# <h2>Age</h2>
# Index(['AG1 0-16', 'AG1 17-18', 'AG1 19-21', 'AG1 22-59', 'AG1 60-64',
#        'AG1 65 plus', 'AG2 0-14', 'AG2 15-24', 'AG2 25-44', 'AG2 45-59',
#        'AG2 60-64', 'AG2 65 plus', 'AGQ 0-4', 'AGQ 10-14', 'AGQ 15-19',
#        'AGQ 20-24', 'AGQ 25-29', 'AGQ 30-34', 'AGQ 35-39', 'AGQ 40-44',
#        'AGQ 45-49', 'AGQ 5-9', 'AGQ 50-54', 'AGQ 55-59', 'AGQ 60-64',
#        'AGQ 65-69', 'AGQ 70-74', 'AGQ 75-79', 'AGQ 80-84', 'AGQ 90 plus',
#        'Age All'],
#       dtype='object')
# <h2>Measure Type</h2>
# Index(['Count'], dtype='object')
# <h2>Unit</h2>
# Index(['people-thousands'], dtype='object')

# %%
tidy['Migration Flow'].cat.categories = tidy['Migration Flow'].cat.categories.map(pathify)
tidy['IPS Citizenship'].cat.categories = tidy['IPS Citizenship'].cat.categories.map(lambda s: pathify(s[4:]))
tidy['Sex'] = tidy['Sex'].cat.rename_categories({
    'Female': 'F',
    'Male': 'M',
    'Persons': 'T'})
tidy['Age'].cat.categories = tidy['Age'].cat.categories.map(
    lambda s: 'all' if s == 'Age All' else pathify(s[:3]) + '/' + pathify(s[4:]))
tidy
# Out:
#        Year          Country of Residence Migration Flow  \
# 0      2017                            eu         inflow
# 1      2017                          eu15         inflow
# 2      2017                           eu8         inflow
# 3      2017                           eu2         inflow
# 4      2017                           eea         inflow
# 5      2017                          efta         inflow
# 6      2017                        non-eu         inflow
# 7      2017                            cw         inflow
# 8      2017                        old-cw         inflow
# 9      2017                        new-cw         inflow
# 10     2017             non-eu-and-non-cw         inflow
# 11     2017                 europe-inc-eu         inflow
# 12     2017                 europe-exc-eu         inflow
# 13     2017                          asia         inflow
# 14     2017  middle-east-and-central-asia         inflow
# 15     2017                     east-asia         inflow
# 16     2017                    south-asia         inflow
# 17     2017               south-east-asia         inflow
# 18     2017                 rest-of-world         inflow
# 19     2017                  north-africa         inflow
# 20     2017            sub-saharan-africa         inflow
# 21     2017                 north-america         inflow
# 22     2017     central-and-south-america         inflow
# 23     2017                       oceania         inflow
# 24     2017                            eu         inflow
# 25     2017                          eu15         inflow
# 26     2017                           eu8         inflow
# 27     2017                           eu2         inflow
# 28     2017                           eea         inflow
# 29     2017                          efta         inflow
# ...     ...                           ...            ...
# 63204  2017                  south-africa        balance
# 63205  2017                         spain        balance
# 63206  2017                     sri-lanka        balance
# 63208  2017                         sudan        balance
# 63210  2017                        sweden        balance
# 63211  2017                   switzerland        balance
# 63213  2017                        taiwan        balance
# 63214  2017                      tanzania        balance
# 63215  2017                      thailand        balance
# 63216  2017           trinidad-and-tobago        balance
# 63217  2017                        turkey        balance
# 63219  2017                        uganda        balance
# 63221  2017          united-arab-emirates        balance
# 63222  2017                           usa        balance
# 63224  2017                       vietnam        balance
# 63227  2017                      zimbabwe        balance
# 63229  2017                      pakistan        balance
# 63233  2017                   philippines        balance
# 63234  2017                        poland        balance
# 63235  2017                      portugal        balance
# 63238  2017                       romania        balance
# 63242  2017                        serbia        balance
# 63248  2017                  south-africa        balance
# 63254  2017                        sweden        balance
# 63266  2017                           usa        balance
# 63282  2017                       romania        balance
# 63317  2017                      pakistan        balance
# 63326  2017                       romania        balance
# 63338  2017                     sri-lanka        balance
# 63354  2017                           usa        balance
#
#                        IPS Citizenship Sex          Age Measure Type  Value  \
# 0                                  all   T          all        Count  253.1
# 1                                  all   T          all        Count  141.9
# 2                                  all   T          all        Count   48.8
# 3                                  all   T          all        Count   52.7
# 4                                  all   T          all        Count    255
# 5                                  all   T          all        Count  259.3
# 6                                  all   T          all        Count  347.6
# 7                                  all   T          all        Count  165.4
# 8                                  all   T          all        Count   60.9
# 9                                  all   T          all        Count  104.5
# 10                                 all   T          all        Count  182.3
# 11                                 all   T          all        Count  272.9
# 12                                 all   T          all        Count   19.9
# 13                                 all   T          all        Count  201.4
# 14                                 all   T          all        Count   24.9
# 15                                 all   T          all        Count   81.3
# 16                                 all   T          all        Count     69
# 17                                 all   T          all        Count   26.2
# 18                                 all   T          all        Count  126.4
# 19                                 all   T          all        Count    2.7
# 20                                 all   T          all        Count   29.5
# 21                                 all   T          all        Count   39.8
# 22                                 all   T          all        Count    8.4
# 23                                 all   T          all        Count     46
# 24                                 all   T      agq/0-4        Count    2.6
# 25                                 all   T      agq/0-4        Count    1.2
# 26                                 all   T      agq/0-4        Count    0.4
# 27                                 all   T      agq/0-4        Count      1
# 28                                 all   T      agq/0-4        Count    2.6
# 29                                 all   T      agq/0-4        Count    2.6
# ...                                ...  ..          ...          ...    ...
# 63204  not-british-or-british-overseas   F    ag2/25-44        Count    2.3
# 63205  not-british-or-british-overseas   F    ag2/25-44        Count   -3.3
# 63206  not-british-or-british-overseas   F    ag2/25-44        Count    0.4
# 63208  not-british-or-british-overseas   F    ag2/25-44        Count      0
# 63210  not-british-or-british-overseas   F    ag2/25-44        Count   -0.5
# 63211  not-british-or-british-overseas   F    ag2/25-44        Count   -0.2
# 63213  not-british-or-british-overseas   F    ag2/25-44        Count    0.5
# 63214  not-british-or-british-overseas   F    ag2/25-44        Count    0.2
# 63215  not-british-or-british-overseas   F    ag2/25-44        Count    0.2
# 63216  not-british-or-british-overseas   F    ag2/25-44        Count    0.6
# 63217  not-british-or-british-overseas   F    ag2/25-44        Count    1.6
# 63219  not-british-or-british-overseas   F    ag2/25-44        Count    0.7
# 63221  not-british-or-british-overseas   F    ag2/25-44        Count    0.8
# 63222  not-british-or-british-overseas   F    ag2/25-44        Count    2.1
# 63224  not-british-or-british-overseas   F    ag2/25-44        Count   -0.1
# 63227  not-british-or-british-overseas   F    ag2/25-44        Count    0.1
# 63229  not-british-or-british-overseas   F    ag2/45-59        Count    0.1
# 63233  not-british-or-british-overseas   F    ag2/45-59        Count    0.1
# 63234  not-british-or-british-overseas   F    ag2/45-59        Count    3.7
# 63235  not-british-or-british-overseas   F    ag2/45-59        Count    0.3
# 63238  not-british-or-british-overseas   F    ag2/45-59        Count    0.3
# 63242  not-british-or-british-overseas   F    ag2/45-59        Count    0.1
# 63248  not-british-or-british-overseas   F    ag2/45-59        Count      1
# 63254  not-british-or-british-overseas   F    ag2/45-59        Count   -0.5
# 63266  not-british-or-british-overseas   F    ag2/45-59        Count    0.1
# 63282  not-british-or-british-overseas   F    ag2/60-64        Count    0.8
# 63317  not-british-or-british-overseas   F  ag2/65-plus        Count    0.1
# 63326  not-british-or-british-overseas   F  ag2/65-plus        Count    0.4
# 63338  not-british-or-british-overseas   F  ag2/65-plus        Count    0.1
# 63354  not-british-or-british-overseas   F  ag2/65-plus        Count   -0.4
#
#          CI              Unit
# 0      29.6  people-thousands
# 1      22.5  people-thousands
# 2      11.6  people-thousands
# 3      13.0  people-thousands
# 4      29.8  people-thousands
# 5      30.1  people-thousands
# 6      26.5  people-thousands
# 7      18.5  people-thousands
# 8      13.1  people-thousands
# 9      13.2  people-thousands
# 10     19.0  people-thousands
# 11     30.9  people-thousands
# 12      8.8  people-thousands
# 13     18.2  people-thousands
# 14      7.0  people-thousands
# 15     11.6  people-thousands
# 16     10.3  people-thousands
# 17      6.3  people-thousands
# 18     17.2  people-thousands
# 19      1.9  people-thousands
# 20      7.3  people-thousands
# 21      9.6  people-thousands
# 22      3.4  people-thousands
# 23     11.7  people-thousands
# 24      2.2  people-thousands
# 25      1.3  people-thousands
# 26      0.8  people-thousands
# 27      1.6  people-thousands
# 28      2.2  people-thousands
# 29      2.2  people-thousands
# ...     ...               ...
# 63204   2.4  people-thousands
# 63205   5.1  people-thousands
# 63206   0.5  people-thousands
# 63208   0.1  people-thousands
# 63210   0.7  people-thousands
# 63211   1.3  people-thousands
# 63213   2.0  people-thousands
# 63214   0.5  people-thousands
# 63215   0.9  people-thousands
# 63216   1.2  people-thousands
# 63217   2.6  people-thousands
# 63219   1.4  people-thousands
# 63221   0.6  people-thousands
# 63222   2.6  people-thousands
# 63224   0.3  people-thousands
# 63227   0.1  people-thousands
# 63229   0.1  people-thousands
# 63233   0.2  people-thousands
# 63234   5.1  people-thousands
# 63235   0.5  people-thousands
# 63238   0.5  people-thousands
# 63242   0.2  people-thousands
# 63248   1.3  people-thousands
# 63254   1.0  people-thousands
# 63266   1.0  people-thousands
# 63282   1.1  people-thousands
# 63317   0.2  people-thousands
# 63326   0.7  people-thousands
# 63338   0.2  people-thousands
# 63354   0.7  people-thousands
#
# [52189 rows x 10 columns]

# %%
out = Path('out')
out.mkdir(exist_ok=True)
tidy.to_csv(out / 'observations.csv', index = False)

# %%
from gssutils.metadata import THEME

scraper.dataset.family = 'migration'
scraper.dataset.theme = THEME['population']
with open(out / 'dataset.trig', 'wb') as metadata:
    metadata.write(scraper.generate_trig())
